# %%
from PIL import Image
from pylab import *
#It is a math graph plotting thingy (Advanced!!!)

# %%
im = array(Image.open(r"C:\Users\cocka\Downloads\slider-img.png"))
#Reading the image

# %%
imshow(im)
#Plot the image

# %%
x = [100,100,400,400]
y = [200,500,200,500]

plot(x,y,'r*')
#Plotting with *

# %%
plot(x[:2],y[:2])
#Plot connecting the two points

title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %%
from PIL import Image
from pylab import *
matplotlib.use('TkAgg')#Becuase we cant print the image inline

im = array(Image.open(r"C:\Users\cocka\Downloads\slider-img.png"))
imshow(im)

print('Please click 3 points')
x = ginput(3)
# Out:
# Please click 3 points

# %%
print('You clicked:',x)
show()
# Out:
# You clicked: [(1191.7580645161293, 579.241935483871), (876.9193548387098, 305.6935483870968), (513.0483870967744, 968.9193548387098)]

# %%
#Image types

# %%
import numpy as np

# %%
image = Image.open(r"C:\Users\cocka\Downloads\slider-img.png")
img_array = np.array(image)

# %%
img_array
# Out:
# array([[[ 24,  79, 145, 255],
#         [ 26,  76, 138, 255],
#         [ 26,  76, 136, 255],
#         ...,
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255]],
#
#        [[ 24,  87, 158, 255],
#         [ 28,  84, 153, 255],
#         [ 26,  80, 147, 255],
#         ...,
#         [  1,   1,   3, 255],
#         [  1,   1,   3, 255],
#         [  1,   1,   3, 255]],
#
#        [[ 60, 127, 194, 255],
#         [ 32,  98, 175, 255],
#         [ 24,  87, 162, 255],
#         ...,
#         [  1,   1,   2, 255],
#         [  1,   1,   2, 255],
#         [  1,   1,   1, 255]],
#
#        ...,
#
#        [[ 38,  44,  60, 255],
#         [ 37,  43,  59, 255],
#         [ 38,  44,  62, 255],
#         ...,
#         [ 12,  10,  11, 255],
#         [ 12,  10,  11, 255],
#         [ 10,   8,   9, 255]],
#
#        [[ 37,  42,  54, 255],
#         [ 37,  44,  55, 255],
#         [ 33,  40,  56, 255],
#         ...,
#         [ 12,  10,  11, 255],
# ...

# %%
img_array.shape
#4 Channels RGBA
# Out:
# (1080, 1920, 4)

# %%
img = Image.open(r"C:\Users\cocka\Downloads\slider-img.png")
img = img.convert('L')

# %%
img = np.array(img)

# %%
img.shape
#NO channels
# Out:
# (1080, 1920)
